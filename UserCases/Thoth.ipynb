# %% [markdown]
# # Example of Thoth Wet Lab Smart Orchestration SCP Server
#
# This example will use both the Thoth-Plan and Thoth-OP services. Among them, the Thoth-OP service will be automatically invoked within the tools of Thoth-Plan.
# The different code blocks in this Jupyter Notebook have variable dependencies and need to be run sequentially in order.

# %%
import json
import os
from typing import List
from mcp.client.streamable_http import streamablehttp_client
from mcp import ClientSession

# Set server addresses
SCP_WORKFLOW_SERVER_URL = "https://scp.intern-ai.org.cn/api/v1/mcp/32/SCP-Workflow" # SCP Workflow server address
THOTH_PLAN_SERVER_URL = "https://scp.intern-ai.org.cn/api/v1/mcp/19/Thoth-Plan" # Thoth-Plan server address

protocols = []

# Define client class
class ToolsClient:
    def __init__(self, server_url: str):
        self.server_url = server_url
        self.session = None

    async def connect(self):
        """Establish connection and initialize session"""
        print(f"\n{'='*80}")
        print("Connecting to synchronous PCR tool MCP server")
        print(f"{'='*80}")
        print(f"Server address: {self.server_url}")

        try:
            # Establish streamable-http transport connection
            self.transport = streamablehttp_client(
                url=self.server_url, 
                sse_read_timeout=60 * 10,
                headers={
                    "SCP-HUB-API-KEY": "XX"  # replace it with your API Key
                }
            )
            self.read, self.write, self.get_session_id = await self.transport.__aenter__()

            # Create client session
            self.session_ctx = ClientSession(self.read, self.write)
            self.session = await self.session_ctx.__aenter__()

            # Initialize session
            await self.session.initialize()
            session_id = self.get_session_id()

            print(f"✓ Connection successful")
            print(f"✓ Session ID: {session_id}")
            print(f"{'='*80}\n")
            return True

        except Exception as e:
            print(f"✗ Connection failed: {e}")
            import traceback
            traceback.print_exc()
            return False

    async def disconnect(self):
        """Disconnect"""
        try:
            if self.session:
                await self.session_ctx.__aexit__(None, None, None)
            if hasattr(self, 'transport'):
                await self.transport.__aexit__(None, None, None)
            print("\n✓ Disconnected\n")
        except Exception as e:
            print(f"✗ Error disconnecting: {e}")

    async def list_tools(self):
        """List all available tools"""
        print(f"\n{'='*80}")
        print("Listing all available tools")
        print(f"{'='*80}")

        try:
            tools_list = await self.session.list_tools()
            print(f"\nAvailable tools (Total {len(tools_list.tools)}):\n")

            for i, tool in enumerate(tools_list.tools, 1):
                print(f"{i:2d}. {tool.name}")
                if tool.description:
                    # Only display first line of description
                    desc_line = tool.description
                    print(f"    {desc_line}")

            print(f"\n✓ Tool list retrieved successfully")
            return tools_list.tools

        except Exception as e:
            print(f"✗ Failed to list tools: {e}")
            return []

    def _parse_result(self, result):
        """Parse MCP tool call result"""
        try:
            if hasattr(result, 'content') and result.content:
                content = result.content[0]
                if hasattr(content, 'text'):
                    return json.loads(content.text)
            return str(result)
        except Exception as e:
            try:
                return result.content[0].text
            except Exception as e2:
                return {"error": f"Failed to parse result: {e}\t{e2}", "raw": str(result)}
        

async def upload_file_via_curl(upload_url: str, file_path: str = "./test.pdf"):
    """Upload file to pre-signed URL using curl command"""
    import subprocess
    
    if not os.path.exists(file_path):
        print(f"✗ File does not exist: {file_path}")
        return False
    
    try:
        # Use curl to upload file
        curl_cmd = f"curl -X PUT '{upload_url}' --upload-file {file_path}"
        print(f"Executing upload command: {curl_cmd}")
        
        result = subprocess.run(curl_cmd, shell=True, capture_output=True, text=True)
        
        if result.returncode == 0:
            print("✓ File uploaded successfully")
            return True
        else:
            print(f"✗ File upload failed:")
            print(f"  stderr: {result.stderr}")
            print(f"  stdout: {result.stdout}")
            return False
            
    except Exception as e:
        print(f"✗ Error uploading file: {e}")
        return False

# %% [markdown]
# ## Generate Protocol Based on User-Uploaded PDF Files

# %%
async def upload_and_generate_protocol() -> str:
    client_file = ToolsClient(server_url=SCP_WORKFLOW_SERVER_URL)
    if not await client_file.connect():
        print("connection failed")
        return
    
    print("Uploading file to the cloud...")
    file_result = await client_file.session.call_tool(
        "generate_presigned_url",
        arguments={
            "key": "test.pdf",
            "expires_seconds": 3600
        }
    )
    file_result_json = client_file._parse_result(file_result)
    
    if "error" in file_result_json:
        print(f"✗ Failed to get presigned URL: {file_result_json}")
        await client_file.disconnect()
        return
        
    upload_url = file_result_json["upload"]["url"]
    download_url = file_result_json["download"]["url"]
    
    print(f"Upload URL: {upload_url}")
    print(f"Download URL: {download_url}")
    
    success = await upload_file_via_curl(upload_url, "./test.pdf")
    
    await client_file.disconnect()

    if not success:
        print("✗ File upload failed, exiting the program")
        return
    
    
    print("Extracting a protocol from the PDF...")
    client = ToolsClient(server_url=THOTH_PLAN_SERVER_URL)
    if not await client.connect():
        print("connection failed")
        return
    
    result = await client.session.call_tool(
        "extract_protocol_from_pdf",
        arguments={
            "pdf_url": download_url
        }
    )
    protocol = client._parse_result(result)
    
    await client.disconnect()
    print("=" * 80)
    print("Extracted protocol from PDF:")
    print("=" * 80)
    print(protocol)
    
    return protocol


protocol_from_pdf = await upload_and_generate_protocol()
protocols.append(protocol_from_pdf)
# Out:
# ================================================================================
# Connecting to synchronous PCR tool MCP server
# ================================================================================
# Server address: https://scp.intern-ai.org.cn/api/v1/mcp/32/SCP-Workflow
# ✓ Connection successful
# ✓ Session ID: 04d0f3d9-95fa-4df3-bbe9-0924b06c3149
# ================================================================================
#
# Uploading file to the cloud...
# Upload URL: https://ai4s-scp.oss-cn-shanghai.aliyuncs.com/2025/12/23/test_065923_c8f8e860.pdf?x-oss-signature-version=OSS4-HMAC-SHA256&x-oss-date=20251223T065923Z&x-oss-expires=3599&x-oss-credential=LTAI5t8mY1oSnxuXrvuLiSkC%2F20251223%2Fcn-shanghai%2Foss%2Faliyun_v4_request&x-oss-signature=fe743b0b2add481d09247564d839316fd89efc208b553e577d9df13786be380f
# Download URL: https://ai4s-scp.oss-cn-shanghai.aliyuncs.com/2025/12/23/test_065923_c8f8e860.pdf?x-oss-signature-version=OSS4-HMAC-SHA256&x-oss-date=20251223T065923Z&x-oss-expires=3599&x-oss-credential=LTAI5t8mY1oSnxuXrvuLiSkC%2F20251223%2Fcn-shanghai%2Foss%2Faliyun_v4_request&x-oss-signature=eb23dd52fe5120e5c6cfe0881c3a5f3607417079d8966ded06f3e1893c1ac8e1
# Executing upload command: curl -X PUT 'https://ai4s-scp.oss-cn-shanghai.aliyuncs.com/2025/12/23/test_065923_c8f8e860.pdf?x-oss-signature-version=OSS4-HMAC-SHA256&x-oss-date=20251223T065923Z&x-oss-expires=3599&x-oss-credential=LTAI5t8mY1oSnxuXrvuLiSkC%2F20251223%2Fcn-shanghai%2Foss%2Faliyun_v4_request&x-oss-signature=fe743b0b2add481d09247564d839316fd89efc208b553e577d9df13786be380f' --upload-file ./test.pdf
# ✓ File uploaded successfully
#
# ✓ Disconnected
#
# Extracting a protocol from the PDF...
#
# ================================================================================
# Connecting to synchronous PCR tool MCP server
# ================================================================================
# Server address: https://scp.intern-ai.org.cn/api/v1/mcp/19/Thoth-Plan
# ✓ Connection successful
# ✓ Session ID: 035252ee-4ead-4ee2-9e74-53cef7d34f58
# ================================================================================
#
#
# ✓ Disconnected
#
# ================================================================================
# Extracted protocol from PDF:
# ================================================================================
# 1. Prepare 5’/3’ primer working stock by diluting each primer 1:10 into a single clean Eppendorf tube from an intial 100 uM stock (ex: 16 uL ddH20 + 2 uL 5’ primer + 2 uL 3’ primer in 20 uL total). Each PCR reaction will require 1 uL of primer mix, but due to pipetting error, it is good practice to generate at least 5-10 extra samples. Final concentration of each primer in the mix in 500 nM.
# 2. To set up the PCR master mix, use the table below: #colonies to screen/#rxns to prep Single reaction 12/16 48/56 96/112 5’/3’ mix 1 16 56 112 2x OneTaq Master Mix 10 160 560 1120 ddH O 9 144 504 1008 Final volume (uL) 20 320 1120 2240; OneTaq 2X Master Mix with Standard Buffer - 500 rxns New England Biolabs Catalog #M0482L
# 3. Pipette 20 mL of PCR master mix into appropriate PCR tubes (keep tubes/plate on ice).
# 4. Using a 10 uL pipette tip, pick a small amount of Phaeodactylum biomass from the patch on an agar plate. This is roughly equivalent to the amount of biomass one would select for screening E coli colonies and is just enough to see the diatom biomass on the end of the tip. If you overload the reaction with biomass, a nonspecific DNA band can be visualized on an agarose gel at roughly 800bp-1kb. Place the tip with biomass into the appropriate PCR tube on ice and leave it there. Continue picking samples from agar plates, placing pipet tips in the PCR mixes on ice.
# 5. If a positive control plasmid is available, add 1 uL of 0.5-1.0 ng/uL purified plasmid to a tube containing 19 uL of PCR master mix or 1 uL of ddH20 for negative/water control.
# 6. Once picking is finished, use a P20 pipet set at 10 uL to pipet each reaction up and down multiple times, releasing the cells from the pipet tip. The color of the reaction will be a light brown if the appropriate amount of biomass was collected. We also suggest using a multichannel pipet for clearing out the tips when a larger number of colonies are being screened (24 and up). If desired, briefly spin the PCR tubes to remove bubbles from pipetting. We have not seen any difference in PCR efficiency when tubes are spun versus leaving in the bubbles.
# 7. Set up the PCR program on thermocycler. Our standard protocol for PCR using OneTaq is: Step 1: 95oC for 2 min; Step 2: 95oC for 10 sec; Step 3: Annealing temp for 20 sec (we often aim for 60oC at this step); Step 4: 72oC for appropriate extension time (1kb/min with OneTaq); Step 5: Go to Step 2 29 additional times (30 total cycles); Step 6: 72oC for 5 min; Step 7: Hold at 10oC or end program; Note: Once the cycles are finished, the samples can be stored at 4oC overnight (-20oC for longer).
# 8. To analyze the reaction on a gel, add 4 uL of 6x DNA loading dye to each tube. Briefly spin the tubes to mix buffer with sample and flick tubes to mix. On a 1% agarose gel, load 16 uL of samples + dye mix. If 1ng of positive control plasmid was used, load 8 uL of final reaction so to not blow out the gel when imaged. Run gel and image with appropriate DNA stain/imaging system. This protocol was developed using gels stained with EtBr and imaged on a BioRad GelDoc XR System. Other systems and stain combinations may require loading more or less of the final PCR reaction.

# %% [markdown]
# ## Generate Protocols Based on User-provided Requirements

# %%
# Multiple user-provided requirements
prompts = [
    # 20 minute PCR enzymatic cleanup procedure
    "Could you describe the full set of laboratory steps used in the patch based colony PCR protocol for screening Phaeodactylum tricornutum?",
    
    # real time PCR assay for detecting viable Dichelobacter nodosus with PMAxx
    "I would like to know every step involved in the real time PCR assay for detecting viable Dichelobacter nodosus with PMAxx. Can you provide the full protocol?",
    
    # highly sensitive detection of the HV69/70 deletion
    "Could you provide the full set of laboratory steps used in the Modified Zhen et al. SARS-CoV-2 Spike-Gene qRT-PCR assay for highly sensitive detection of the HV69/70 deletion?",
    
    # patch based colony PCR protocol for screening Phaeodactylum tricornutum
    "Could you describe the full set of laboratory steps used in the patch based colony PCR protocol for screening Phaeodactylum tricornutum?",
    
    # perform the Illumina TruSeq library quantification using the qPCR probe method
    "How do you perform the Illumina TruSeq library quantification using the qPCR probe method? Please describe the complete protocol.",
    
    # converting RNA to cDNA and then carrying out the RT PCR procedure
    "Could you outline the entire workflow for converting RNA to cDNA and then carrying out the RT PCR procedure, including all steps in the protocol?",
    
    # Ultra Rapid PCR sequencing
    "Could you explain the full experimental process for carrying out the Ultra Rapid PCR sequencing protocol?",
    
    # Rubella virus real time RT PCR assay
    "Please explain the complete procedure for performing the Rubella virus real time RT PCR assay, including every step from start to finish.",
    
    # standard Colony PCR
    "What is the complete procedure for performing a standard Colony PCR experiment?",
    
    # SARS-CoV-2 McGill ARTIC PCR protocol
    "Can you describe all steps required to run the SARS-CoV-2 McGill ARTIC PCR protocol using 2.5 µl RT with V3-only primers and LA1?"
]


async def generate_protocol(prompts: List[str]):
    generated_protocols = []
    
    client = ToolsClient(server_url=THOTH_PLAN_SERVER_URL)
    if not await client.connect():
        print("connection failed")
        return
    
    for prompt_id, prompt in enumerate(prompts):
        result = await client.session.call_tool(
            "protocol_generation",
            arguments={
                "user_prompt": prompt
            }
        )
        protocol = client._parse_result(result)
        
        print("=" * 80)
        print(f"USER QUERY #{prompt_id + 1}: {prompt}")
        print("GENERATED PROTOCOL:")
        print(protocol)
        
        generated_protocols.append(protocol)
        
    await client.disconnect()
        
    return generated_protocols
    

protocols.extend(await generate_protocol(prompts))
# Out:
# ================================================================================
# Connecting to synchronous PCR tool MCP server
# ================================================================================
# Server address: https://scp.intern-ai.org.cn/api/v1/mcp/19/Thoth-Plan
# ✓ Connection successful
# ✓ Session ID: 75429e86-0fdf-43b5-a5ee-589753c934a4
# ================================================================================
#
# ================================================================================
# USER QUERY #1: Could you describe the full set of laboratory steps used in the patch based colony PCR protocol for screening Phaeodactylum tricornutum?
# GENERATED PROTOCOL:
# 1. Prepare 5’/3’ primer working stock by diluting each primer 1:10 into a single clean Eppendorf tube from an initial 100 uM stock (ex: 16 uL ddH20 + 2 uL 5’ primer + 2 uL 3’ primer in 20 uL total). Each PCR reaction will require 1 uL of primer mix, but due to pipetting error, it is good practice to generate at least 5-10 extra samples. Final concentration of each primer in the mix in 500 nM.
# 2. To set up the PCR master mix, use the table below: #colonies to screen/#rxns to prep Single reaction 12/16 48/56 96/112 5’/3’ mix 1 16 56 112 2x OneTaq Master Mix 10 160 560 1120 ddH O 9 144 504 1008 Final volume (uL) 20 320 1120 2240; OneTaq 2X Master Mix with Standard Buffer - 500 rxns New England Biolabs Catalog #M0482L
# 3. Pipette 20 mL of PCR master mix into appropriate PCR tubes (keep tubes/plate on ice).
# 4. Using a 10 uL pipette tip, pick a small amount of Phaeodactylum biomass from the patch on an agar plate. This is roughly equivalent to the amount of biomass one would select for screening E coli colonies and is just enough to see the diatom biomass on the end of the tip. If you overload the reaction with biomass, a nonspecific DNA band can be visualized on an agarose gel at roughly 800bp-1kb; 4.1 Place the tip with biomass into the appropriate PCR tube on ice and leave it there; 4.2 Continue picking samples from agar plates, placing pipet tips in the PCR mixes on ice
# 5. If a positive control plasmid is available, add 1 uL of 0.5-1.0 ng/uL purified plasmid to a tube containing 19 uL of PCR master mix or 1 uL of ddH20 for negative/water control.
# 6. Once picking is finished, use a P20 pipet set at 10 uL to pipet each reaction up and down multiple times, releasing the cells from the pipet tip. The color of the reaction will be a light brown if the appropriate amount of biomass was collected; 6.1 We also suggest using a multichannel pipet for clearing out the tips when a larger number of colonies are being screened (24 and up); 6.2 If desired, briefly spin the PCR tubes to remove bubbles from pipetting. We have not seen any difference in PCR efficiency when tubes are spun versus leaving in the bubbles
# 7. Set up the PCR program on thermocycler; 7.1 Step 1: 95oC for 2 min; 7.2 Step 2: 95oC for 10 sec; 7.3 Step 3: Annealing temp for 20 sec (we often aim for 60oC at this step); 7.4 Step 4: 72oC for appropriate extension time (1kb/min with OneTaq); 7.5 Step 5: Go to Step 2 29 additional times (30 total cycles); 7.6 Step 6: 72oC for 5 min; 7.7 Step 7: Hold at 10oC or end program; Note: Once the cycles are finished, the samples can be stored at 4oC overnight (-20oC for longer)
# 8. To analyze the reaction on a gel, add 4 uL of 6x DNA loading dye to each tube; 8.1 Briefly spin the tubes to mix buffer with sample and flick tubes to mix; 8.2 On a 1% agarose gel, load 16 uL of samples + dye mix. If 1ng of positive control plasmid was used, load 8 uL of final reaction so to not blow out the gel when imaged; 8.3 Run gel and image with appropriate DNA stain/imaging system. This protocol was developed using gels stained with EtBr and imaged on a BioRad GelDoc XR System. Other systems and stain combinations may require loading more or less of the final PCR reaction
# ================================================================================
# USER QUERY #2: I would like to know every step involved in the real time PCR assay for detecting viable Dichelobacter nodosus with PMAxx. Can you provide the full protocol?
# GENERATED PROTOCOL:
# 1. place or dissolve your sample containing Dichelobacter nodosus in a total voulme of 50 µl 0.85% NaCl in a transparent 1.5 ml tube
# 2. in a darkened room add 100 µM (0.25 µl) of PMAxx™ to the tube
# 3. vortex and incubate for 3 min at room temperature in a metal box impervious to light
# 4. after incubation, place tube on ice and expose to LED light (white light, 100 W, 6000 K, 8500 lm) at a distance of 20 cm for 5 min
# 5. centrifuge tube at 15'000xg for 5 min in a microcentrifuge
# 6. to remove the supernatant, the tubes can be held in a horizontal position and twisted tissues used to absorb the liquid
# 7. resuspend pellet in 500 µl SV-lysis buffer (4 M guanidine thiocyanate, 0.01M Tris–HCl, 1% β-mercaptoethanol)
# 8. add 2 µl of VetMAX™ Xeno™ Internal Positive Control DNA to the sample in SV-lysis buffer (this is the extraction control and later also the internal PCR control)
# 9. add 30 µl MagneSil®RED and resuspend without vortexing
# 10. extract DNA using KingFisher™ Duo Prime Purification System (or an alternative magnetic bead based system) and elute the purified DNA in 60 µl H2O
# 11. primers and probes as well as the real-time PCR are described in the publications 116. Dnodosus PCR.pdf 140. Dnodosus infection SAT.pdf
# 12. prepare 25 µl containing: - 1x TaqMan™ Fast Advanced Master Mix - 300 nM primer DnAprTM-L (CAATAGCCAAATTTCTTTAGATGGTGAT) - 300 nM DnAprTM-R (CAAGAGCTGTCGCTTCTTTCTTT) - 100 nM Probe DnAprTm-v (FAM-CGGTGGTTATCCTGAT-MGB) - 250 nM Probe DnAprTM-b (VIC-TGGTCGTCCTGATC-MGB) - pyrogen-free water - 1 µl Xeno™ LIZ Primer Probe Mix and 2.5 µl of DNA template
# 13. prepare at least duplicates for each sample and run on an appropriate instrument like 7500 Real-Time PCR-System instrument
# 14. run using cycles of 2 min at 50°C and 10 min at 95°C followed by 40 cycles with 15 s at 95°C and 1 min at 60°C
# 15. results are analyzed using the Sequence Detector 7500 software (v 2.3.) with the threshold set at 0.015
# 16. signals will only result from alive D. nodosus and no dead cell will be detected. For absolute quantification a standard curve using defined amounts of D. nodosus genome equivalents can be generaded in parallel
# ================================================================================
# USER QUERY #3: Could you provide the full set of laboratory steps used in the Modified Zhen et al. SARS-CoV-2 Spike-Gene qRT-PCR assay for highly sensitive detection of the HV69/70 deletion?
# GENERATED PROTOCOL:
# 1 Modified Primer/Probe set based on Zhen et al., (J Mol Diagn, 2020): (5' - 3'); S-gene fwd; TCAACTCAGGACTTGTTCTTAC; S-gene rev; TGGTAGGACAGGGTTATCAAAC; S-gene P-1; FAM-TGGTCCAGAGACATGATM-SC; S-gene P-2; SC-BHQ1-TGGTCGAGGACATGATM-SC; Block-it; Q5' - 6BHQ2-CCCTTCCCAGAGGTCM-BHQ1. Note: "SC" is a common primer arm. Primers and Probes were custom made and ordered from TIB MOL (Berlin, Germany) and Ella Biotech (Martinsried, Germany). }; 2 Prepare a 4x primer/probe stock (500µL, for 100 reactions); 3 Add 5µL of 4x primer/probe mix to 4x RT-PCR master mix (500µL, for 100 reactions); 4 Adjust annealing temperature to 60°C for all assays; 5 Incubate for 2 minutes at 55°C; 6 Incubate for 2 minutes at 95°C; 7 Incubate for 30 minutes at 60°C; 8 Incubate for 5 minutes at 95°C; 9 Measure fluorescent signals; 10 Adjust Q5® RT-PCR reaction as follows: SuperScript® III Platinum One-Step qRT-PCR® Kit 2x Mix (500µL, for 100 reactions) 1x; Nuclease-free water 500µL, for 100 reactions; 4x primer/probe 500µL, for 100 reactions); 11 Incubate in a thermocycler according to the following program: Step 1; 95°C for 2 minutes; Step 2; 95°C for 3 seconds; Step 3; Annealing temperature for 20 seconds (variable depending on primer/Probe set); Step 4; 72°C for 3 seconds (fixed); Step 5; Go to Step 1 if no PCR product was detected in a screen-in reaction; Step 6; Repeat Steps 2–6 for 39 cycles (5% margin for indels). Note: 30 µM primer concentration was used in a 5' - 3' annealing in 200x500µL reaction; 12 Decapacitate the PCR tubes after use and store them at 5-8°C; 13 Primers and Probes could also be used with the following PCR software: Probe 665/590; Block-it 635/540; Generice 630/560; SuperScript® III Platinum One-Step qRT-PCR 630/560. Note: Adjust detection channel if necessary. }); 14 Possible outcomes of PCR: 14.1 Strong positive signal for S-gene; 14.2 Strong strong signal for Block-it (genomic DNA contamination); 14.3 Signal only for S-gene P-2 and not for Block-it (possible somatic mutation or dead cell contamination); 14.4 No signal within 40 cycles (negative result). Note: 14.1-3 refer to the expected signals of a positive control curve. A 10x dilution series of a SARS-CoV-2 strain or a clinical sample can be used to confirm these results. 14.4 is a negative control.}; 15 1. Prepare a 4x RT-PCR master mix (500µL, for 100 reactions); 16 1.1 Add 1µL of SuperScript® III Platinum One-Step qRT-PCR® 2x Master Mix to each well; 16 1.2 Add 1µL of Nuclease-free water to each well; 16 1.3 Add 3µL of primer/probe mix to each well}; 17 2. Add 4µL of sample RNA to 1µL of master mix per well; 18 3. Start PCR in a thermocycler}; 19 4. Place the PCR plate/Tube in a thermocycler; 19 4.1 Incubate at 55°C for 2 minutes; 19 4.2 Incubate at 95°C for
# ================================================================================
# USER QUERY #4: Could you describe the full set of laboratory steps used in the patch based colony PCR protocol for screening Phaeodactylum tricornutum?
# GENERATED PROTOCOL:
# 1. Prepare 5’/3’ primer working stock by diluting each primer 1:10 into a single clean Eppendorf tube from an initial 100 uM stock (ex: 16 uL ddH20 + 2 uL 5’ primer + 2 uL 3’ primer in 20 uL total). Each PCR reaction will require 1 uL of primer mix, but due to pipetting error, it is good practice to generate at least 5-10 extra samples. Final concentration of each primer in the mix in 500 nM.
# 2. To set up the PCR master mix, use the table below: #colonies to screen/#rxns to prep Single reaction 12/16 48/56 96/112 5’/3’ mix 1 16 56 112 2x OneTaq Master Mix 10 160 560 1120 ddH O 9 144 504 1008 Final volume (uL) 20 320 1120 2240; OneTaq 2X Master Mix with Standard Buffer - 500 rxns New England Biolabs Catalog #M0482L
# 3. Pipette 20 mL of PCR master mix into appropriate PCR tubes (keep tubes/plate on ice).
# 4. Using a 10 uL pipette tip, pick a small amount of Phaeodactylum biomass from the patch on an agar plate. This is roughly equivalent to the amount of biomass one would select for screening E coli colonies and is just enough to see the diatom biomass on the end of the tip. If you overload the reaction with biomass, a nonspecific DNA band can be visualized on an agarose gel at roughly 800bp-1kb; 4.1 Place the tip with biomass into the appropriate PCR tube on ice and leave it there; 4.2 Continue picking samples from agar plates, placing pipet tips in the PCR mixes on ice
# 5. If a positive control plasmid is available, add 1 uL of 0.5-1.0 ng/uL purified plasmid to a tube containing 19 uL of PCR master mix or 1 uL of ddH20 for negative/water control.
# 6. Once picking is finished, use a P20 pipet set at 10 uL to pipet each reaction up and down multiple times, releasing the cells from the pipet tip. The color of the reaction will be a light brown if the appropriate amount of biomass was collected; 6.1 We also suggest using a multichannel pipet for clearing out the tips when a larger number of colonies are being screened (24 and up); 6.2 If desired, briefly spin the PCR tubes to remove bubbles from pipetting. We have not seen any difference in PCR efficiency when tubes are spun versus leaving in the bubbles
# 7. Set up the PCR program on thermocycler; 7.1 Step 1: 95oC for 2 min; 7.2 Step 2: 95oC for 10 sec; 7.3 Step 3: Annealing temp for 20 sec (we often aim for 60oC at this step); 7.4 Step 4: 72oC for appropriate extension time (1kb/min with OneTaq); 7.5 Step 5: Go to Step 2 29 additional times (30 total cycles); 7.6 Step 6: 72oC for 5 min; 7.7 Step 7: Hold at 10oC or end program; Note: Once the cycles are finished, the samples can be stored at 4oC overnight (-20oC for longer)
# 8. To analyze the reaction on a gel, add 4 uL of 6x DNA loading dye to each tube; 8.1 Briefly spin the tubes to mix buffer with sample and flick tubes to mix; 8.2 On a 1% agarose gel, load 16 uL of samples + dye mix. If 1ng of positive control plasmid was used, load 8 uL of final reaction so to not blow out the gel when imaged; 8.3 Run gel and image with appropriate DNA stain/imaging system. This protocol was developed using gels stained with EtBr and imaged on a BioRad GelDoc XR System. Other systems and stain combinations may require loading more or less of the final PCR reaction
# ================================================================================
# USER QUERY #5: How do you perform the Illumina TruSeq library quantification using the qPCR probe method? Please describe the complete protocol.
# GENERATED PROTOCOL:
# 1. Prepare low-TE buffer (10 mM Tris-HCl, 0.1 mM EDTA, pH 8.0) containing 5 ng/μl salmon sperm DNA; 1 M Tris-HCl, pH8.0 100 μl; 0.5 M EDTA 10 μl; UltraPure™DNA Solution 10 mg/mL 5 μl; milli-Q water 9889 μl; Total 10 mL; Store in -20 °C.
# 2. Prepare dilution series of PhiX control with low-TE buffer containing 5 ng/μl salmon sperm DNA in 8-strip PCR tubes; These are used as calibrators; 50 pM 100 μl; 5 pM 100 μl; 0.5 pM 100 μl; 0.05 pM 100 μl; Store in -20 °C.
# 3. Prepare 20x primers & probe mix solution as below; Probe 5 μM; P5 primer 5 μM; P7 primer 5 μM; Store in -20 °C; Double-quenched probe (IDT): /56-FAM/ACACTCTTT/ZEN/CCCTACACGACGCTCTTC/3IABkFQ/; P5 primer: 5'-AATGATACGGCGACCACCGA-3'; P7 primer: 5'-CAAGCAGAAGACGGCATACGA-3’.
# 4. Prepare the following qPCR master mix per reactions for the number of your samples (+ calibrators); Prime Time PCR master mix 10 μl; 20x primers & probe mix 1 μl; H2O 8 μl; Distribute above to each well; 4.1 Add 1 μl of template (diluted library or calibrator) to each well.
# 5. Conduct PCR with the following condition; 95 °C for 2 min; 30 cycles of 97 °C for 5s; 62 °C for 10s; 68 °C for 15s (photo with a filter appropriate for SYBR-green or FAM).
# 6. Calculate the original concentration of your library.
# ================================================================================
# USER QUERY #6: Could you outline the entire workflow for converting RNA to cDNA and then carrying out the RT PCR procedure, including all steps in the protocol?
# GENERATED PROTOCOL:
# 1. Prepare the RT reaction mix; 2X buffer mix : 10 µL; 20X RT enzyme Mix: 1 µL; RNA sample: < 9 µL; Nuclease-free water: quantity sufficient to 20 µL; Total per reaction: 20 µL
# 2. Prepare the reverse transcription reactions: Aliquot 20 µL RT reaction mix into each well; Seal the plates and centrifuge to spin down the contents and remove air bubbles; Store them on ice
# 3. Perform reverse transcription: Step1: Temp. 37 °C , time: 60 mins; Step2: Temp. 95 °C , time: 5 mins; Step3: Temp. 4 °C , time: unlimited; Store the cDNA: Short-term: < 24 hours before use and store at 2−8°C; Long-term: store at −25°C to −15°C
# 4. For one reaction: Fast SYBR® Green Master Mix (2✕) : 10 µL; Forward and Reverse Primers : variable; cDNA template + RNase-free water: variable; Total: 20 µL; Mix by gentle inversion, then centrifuge the tube to spin down the contents and eliminate any air bubbles
# 5. Transfer the appropriate volume of each reaction to 384-well reaction plate
# 6. Instrument: 7900HT; AmpliTaq Fast DNA Polymerase, UP Activation : Temp. 95 °C , time 10 mins, Cycles HOLD; Reaction volume: 20 µL; MicroAmp Optical 384-Well Reaction Plate; Denature : Temp. 95 °C , time 1second; Temp. 60 °C , time 20 seconds; Anneal/extend: Temp.95 °C , time 15 seconds; Temp. 60 °C , time 15 seconds; Temp. 95 °C , time 15 seconds
# ================================================================================
# USER QUERY #7: Could you explain the full experimental process for carrying out the Ultra Rapid PCR sequencing protocol?
# GENERATED PROTOCOL:
# 1 Prepare the PCR reaction tube by mixing the following components in a 0.2 mL PCR tube; 12.5 µL Q5 Hot Start High-Fidelity 2X Master Mix - 500 rxns New England Biolabs Catalog #M0494L; 1.25 µL forward primer; 1.25 µL reverse primer; 9 µL Nuclease-free Water
# 2 Prepare the DNA extraction tube by mixing the following components in a 2 mL Eppendorf tube; 500 µL of Epicentre QuickExtract™ DNA Extraction Solution Epicentre Catalog #QE09050
# 3 Pre-heat thermocycler and pause for combined PCR and fragmentation protocol Pre-heat two heat blocks (65 °C and 98 °C ) DNA Extraction (in heat blocks) 65 °C for 00:06:00 98 °C for 00:02:00 PCR (in thermocycler) 98 °C for 00:00:30 28 cycles of 98 °C for 00:00:05 64 °C for 00:00:05 72 °C for 00:00:08 72 °C for 00:00:30 hold at 20 °C Fragmentation (in thermocycler) 30 °C for 00:01:00 80 °C for 00:01:00 hold at 20 °C 11m 18s
# 4 When acquired, place 20 µg tumor tissue into 2 mL DNA extraction tube
# 5 Vortex on high for 00:00:10
# 6 Place in pre-heated heat block at 65 °C briefly vortex after 3 minutes of incubation
# 7 Place in pre-heated heat block at 98 °C
# 8 Remove tube, vortex briefly, spin down
# 9 Incubate on ice for 00:00:30
# 10 Add 1 µL extracted DNA to PCR reaction tube
# 11 Place in thermocycler and unpause combined protocol
# 11.1 During PCR, prepare ONT tagmentation mix by mixing the following in a 0.2 mL PCR tube 2.5 µL FRA (Fragmentation Mix) Oxford Nanopore Technologies Catalog #SQK-RAD004
# 11.2 During PCR, prepare ONT sequencing buffer 34 µL SQB (Sequencing Buffer) Oxford Nanopore Technologies Catalog #SQK-RAD004 SQB 10s 8m 30s 25.5 µL LB (Loading Beads) Oxford Nanopore Technologies Catalog #SQK-RAD004 4.5 µL nuclease free water
# 11.3 During PCR, prepare ONT flush buffer Add 30 µL FLT (Flush Tether) Oxford Nanopore Technologies Catalog #EXP-FLP002 into tube of FB (Flush Buffer) Oxford Nanopore Technologies Catalog #EXP-FLP002 Mix and spin down
# 11.4 Prime flow cell with 800 µL of mixed FB (Flush Buffer) Oxford Nanopore Technologies Catalog #EXP-FLP002 and let incubate for 00:05:00
# 11.5 Start sequencing run in MinKNOW software and pause run immediately after flow cell QC check
# 12 Let thermocycler run through the PCR protocol
# 13 Either let thermocycler draw DNA down to room temperature or quench in ice for 00:00:10 . Pause thermocycler program to pre-heat for ONT rapid library preparation tagmentation.
# 14 Add 7.5 µL PCR product to tagmentation mix tube, flick to mix, and spin down
# 15 Place in thermocycler and unpause combined protocol
# 16 Let thermocycler run through fragmentation protocol
# 17 Either let thermocycler draw DNA down to room temperature or quench in ice for 00:00:10
# 18 Add 1 µL ONT Rapid Adapter to tagmentation tube, flick to mix, and spin down
# 19 Incubate sequencing library for 00:05:00 at room temperature, flicking to mix occasionally and spinning down
# 19.1 During the final 1m of incubation, re-prime the ONT flow-cell with SpotOn port open, using 200 µL of FB (Flush Buffer) Oxford Nanopore Technologies Catalog #EXP-FLP002 loading buffer
# 20 Add the entire 11
# ================================================================================
# USER QUERY #8: Please explain the complete procedure for performing the Rubella virus real time RT PCR assay, including every step from start to finish.
# GENERATED PROTOCOL:
# 1. Name 5'-3' RubV TAQMAN FWD 2015 TGATACCCAGACCTGTDTTCAC RubV TAQMAN REV 2015 GGTCGATGAGGACGTGTAGG RubV TAQMAN PRB 2015 6FAM - GATCACCCAGCACTCCACGCAA – BHQ-1
# 2. Assay has been used on both a Rotor-Gene 6000 / Rotor-Gene Q 5-plex using 100- place rotor discs. Total reaction volume is 20µL. Prepare sufficient for number of reaction plus a 'dead volume' usually 2 extra. Adjust as necessary if using a robotic dispenser; Reagent Vol (µL) x1 Final reaction concentration Nuclease free water 4.35 RubV TAQMAN FWD 2015 200pmol/µl 0.09 900nM RubV TAQMAN REV 2015 200pmol/µl 0.09 900nM RubV TAQMAN PRB 2015 100pmol/µl 0.03 150nM 2X Reaction Mix 10 1X SuperScript® III/Platinum® Taq Mix 0.4 1X ROX Reference Dye (25µM) 0.04 50nM TOTAL VOLUME 15 ¹SuperScript® III Platinum® One-Step qRT-PCR®™ Kit, Cat No. 11732088 SuperScript™ III Platinum™ One-Step qRT-PCR Kit Life Technologies Catalog #11732088 Note
# 3. The assay has been optimised and validated for the Rotor-Gene 6000 and Rotor-Gene Q thermocyclers
# 3.1. Incubate at 50°C for 5 minutes 1X
# 3.2. Incubate at 95°C for 2 minutes 1X
# 3.3. Incubate at 95°C for 3 seconds 40X
# 3.4. Incubate at 60°C for 30 seconds* *Florescence acquisition step
# 4. The definition used for a satisfactory positive result from a real-time fluorogenic PCR should include each of the following
# 4.1. A sigmoidal curve – the trace travels horizontally, curves upward, continues in an exponential rise and followed by a curve towards a horizontal plateau phase
# 4.2. A suitable level of fluorescence intensity as measured in comparison to a positive control (y-axis)
# 4.3. A defined threshold (CT) value which the fluorescent curve has clearly exceeded (Fig.1 arrow) and which sits early in the log-linear phase and is <40 cycles
# 4.4. A flat or non-sigmoidal curve or a curve that crosses the threshold with a CT value >40 cycles is considered a negative result
# 4.5. NTCs should not produce a curve
# ================================================================================
# USER QUERY #9: What is the complete procedure for performing a standard Colony PCR experiment?
# GENERATED PROTOCOL:
# 1. Dissolve one colony in 20 µL of nuclease-free water and heat at 80°C for 10 minutes.
# 2. Prepare the following 50 uL reaction in a 0.2mL PCR tube on ice; Magnesium chloride (MgCl2) 25 mM 4 µL 5X Colorless GoTaq Buffer 5 µL PCR Nucleotide Mix 10 mM 0.5 µL Forward primer 10 uM 1 µL Reverse primer 10 uM 1 µL GoTaq DNA polymerase (5u/uL) 0.2 µL DNA Colony 10 µL Nuclease-free water 3.3 µL TOTAL 25 µL
# 3. Gently mix the reaction and spin down in the microcentrifuge
# 4. Cycling conditions for a routine PCR: 1 Cycle Initial activation 2 minutes 94ºC 35 Cycles Denaturation 30 seconds 94ºC Alignment 30 seconds 50ºC Extension 2 minutes 72ºC 1 Cycle 72ºC Maintenance ∞ 4ºC
# ================================================================================
# USER QUERY #10: Can you describe all steps required to run the SARS-CoV-2 McGill ARTIC PCR protocol using 2.5 µl RT with V3-only primers and LA1?
# GENERATED PROTOCOL:
# 1 PRIMER POOL PREPARATION If required resuspend lyophilised primers at a concentration of 100 µM each
# 2 Generate primer pool stocks by adding 5 µL of each primer pair to a 1.5 mL Eppendorf labelled either “Pool 1 (100 µM)” or “Pool 2 (100 µM)”; Total volume should be 490 µL for Pool 1 (100 µM) and 490 µL for Pool 2 (100 µM); These are your 100 µM stocks of each primer pool; 2.1 Make another primer pool named "Pool LA1 (100 µM)" that contains 5 µl of primer pairs 5, 17, 23, 26, 66, 70, 74, 91, 97, and 10 ul of primer pair 64
# 3 Dilute this primer pool 1:10 in molecular grade water, to generate 10 µM primer stocks; It is recommend that multiple aliquots of each primer pool are made to in case of degradation or contamination; 3.1 LA1 primer pool will be diluted to 1 µM primer stock
# 4 MULTIPLEX PCR In the extraction and sample addition cabinet add 2.5 µL RT product to each tube and mix well by pipetting
# 5 In the mastermix hood set up the multiplex PCR reactions as follows in 0.2mL 8-strip PCR tubes: Component Pool 1 [10 uM primer] Pool 2 [10 uM] Pool LA1 [1 uM] Q5 Hot Start High-Fidelity 2X Master Mix 12.5 µL 12.5 µL 12.5 µL Primer Pool 1 or 2 (10 µM pool 1+2; 1 µM LA1) 3.7 µL 3.7 µL 3.7 µL Nuclease-free water 6.3 µL 6.3 µL 6.3 µL Total 22.5 µL 22.5 µL 22.5 µL; 5.1 Add 2.5 µl RT product as mentioned in step 10
# 6 Pulse centrifuge the tubes to collect the contents at the bottom of the tube
# 7 Set-up the following program on the thermal cycler: Step Temperature Time Cycles Heat Activation 98 °C 00:00:30 1 Denaturation 98 °C 00:00:15 36 Annealing 65 °C 00:05:00 36 Hold 4 °C Indefinite 1
# 8 PCR CLEANUP Combine the entire contents of “Pool 1” and “Pool 2” PCR reactions for each biological sample into to a single 1.5 mL Eppendorf tube; Keep Pool LA1 separate from the combined Pool 1+2 until after the clean-up!!
# 9 Clean-up the amplicons using the following protocol; 9.1 Add an equal volume (1:1) of SPRI beads to the sample tube and mix gently by either flicking or pipetting; 9.2 Incubate for 5 min at room temperature; 9.3 Pellet on magnet for 5 min; 9.4 Remove supernatant; 9.5 Add 200 ul of 80% ethanol to the pellet and wash twice; 9.6 Elute in 30 ul elution buffer
# 10 AMPLICON QUANTIFICATION AND NORMALIZATION Quantify the amplicon pools using a fluorimetric dsDNA assay; We expect following concentrations: Pool 1+2 combined: 100-150 ng/ul for Ct 14-24 30-80 ng/ul for Ct 25-29 10-30 ng/ul for Ct 30-36 Pool LA1: 1-10 ng/ul for all Ct
# 11 After quantification of Pool 1+2 and Pool LA1, mix them together in following ratio: 89.8% Pool 1+2 and 10.2% Pool LA1; 11.1 For this, take a new plate and add 135 ng of Pool 1+2 and 15.3 ng of Pool LA1, and add up with nuclease-free water to a total volume of 30 µl (= 150 ng or 5 ng/µl)
#
# ✓ Disconnected

# %% [markdown]
# ## Convert Protocols to Executable JSON and Send to Thoth-OP for Execution

# %%
async def execute_json(protocols: List[str]):
    client = ToolsClient(server_url=THOTH_PLAN_SERVER_URL)
    if not await client.connect():
        print("connection failed")
        return
    
    for protocol_id, protocol in enumerate(protocols):
        prot_desc = f"the protocol generated given user query #{protocol_id}" if protocol_id > 0 else "the protocol generated given user-uploaded PDF file"
        print(f"Converting the protocol to an executable JSON for {prot_desc}...")
        result = await client.session.call_tool(
            "generate_executable_json",
            arguments={
                "protocol": protocol
            }
        )
        executable_json = client._parse_result(result)
        
        print(f"Executing the JSON for {prot_desc}...")
        result = await client.session.call_tool(
            "execute_json",
            arguments={
                "executable_json": json.dumps(executable_json)
            }
        )
        execution_info = client._parse_result(result)
        print("Execution information:")
        print(execution_info)
        print("=" * 20)
        
    await client.disconnect()
    
await execute_json(protocols)
# Out:
# ================================================================================
# Connecting to synchronous PCR tool MCP server
# ================================================================================
# Server address: https://scp.intern-ai.org.cn/api/v1/mcp/19/Thoth-Plan
# ✓ Connection successful
# ✓ Session ID: 1433e3f1-89c1-464d-9fba-d678020e7b19
# ================================================================================
#
# Converting the protocol to an executable JSON for the protocol generated given user-uploaded PDF file...
# Executing the JSON for the protocol generated given user-uploaded PDF file...
# Execution information:
# 1. Preparing 5'/3' primer working stock (volume: 20:microliter) at 500 nM each primer in primer_mix_tube.
# 2. Preparing PCR master mix (volume: 20:microliter) in pcr_master_mix_tube.
# 3. Transferring from pcr_master_mix_tube to pcr_tube, volume: 20:microliter.
# 4. Transferring from pcr_master_mix_tube to positive_control_tube, volume: 19:microliter.
# 5. Adding purified plasmid (0.5-1.0 ng/uL) to positive_control_tube, volume: 1:microliter.
# 6. Transferring from pcr_master_mix_tube to negative_control_tube, volume: 19:microliter.
# 7. Adding ddH2O to negative_control_tube, volume: 1:microliter.
# 8. Performing pipetting (volume: 10:microliter) from pcr_tube to pcr_tube using pipetting_up_down technique.
# 9. Running thermocycle on pcr_tube (volume: 20:microliter).
# 10. Adding 6x DNA loading dye to pcr_tube, volume: 4:microliter.
# 11. Spinning container pcr_tube for 5 second.
# 12. Running gel electrophoresis and imaging for pcr_tube (1.0% gel) with Ethidium Bromide stain.
# ====================
# Converting the protocol to an executable JSON for the protocol generated given user query #1...
# Executing the JSON for the protocol generated given user query #1...
# Execution information:
# 1. Preparing 5'/3' primer working stock (volume: 20:microliter) at 500 nM each primer in primer_mix_tube.
# 2. Preparing PCR master mix (volume: 20:microliter) in pcr_master_mix_tube.
# 3. Transferring from pcr_master_mix_tube to pcr_tube, volume: 20:microliter.
# 4. Inserting pipette tip with biomass into PCR tube on ice.
# 5. Transferring from 0.5-1.0 ng/uL purified plasmid to positive_control_tube, volume: 1:microliter.
# 6. Performing pipetting (volume: 10:microliter) from pcr_tube to pcr_tube using pipetting up and down technique.
# 7. Spinning container pcr_tube for 30 second.
# 8. Running thermocycle on pcr_tube (volume: 20:microliter).
# 9. Adding 6x DNA loading dye to pcr_tube, volume: 4:microliter.
# 10. Spinning container pcr_tube for 30 second.
# 11. Running gel electrophoresis and imaging for pcr_tube (1.0% gel) with Ethidium Bromide stain.
# ====================
# Converting the protocol to an executable JSON for the protocol generated given user query #2...
# Executing the JSON for the protocol generated given user query #2...
# Execution information:
# 1. Preparing Dichelobacter nodosus sample in 0.85% NaCl (volume: 50 microliter) in sample_tube_1.5ml.
# 2. Adding PMAxx™ to sample_tube_1.5ml, volume: 0.25 microliter (100 µM).
# 3. Vortexing sample_tube_1.5ml for 3 minute.
# 4. Incubating container sample_tube_1.5ml at metal_box_impervious_to_light for 3 minute at 25 degC.
# 5. Placing sample_tube_1.5ml at ice for 5 minute.
# 6. Inactivating sample_tube_1.5ml using LED_light_exposure method with LED_light for 5 minute.
# 7. Centrifuging sample_tube_1.5ml at 15000:g for 5 minute.
# 8. Decanting from sample_tube_1.5ml - supernatant.
# 9. Resuspending pellet in SV-lysis_buffer (volume: 500 microliter) in sample_tube_1.5ml.
# 10. Adding VetMAX™ Xeno™ Internal Positive Control DNA to sample_tube_1.5ml, volume: 2 microliter.
# 11. Adding MagneSil®RED to sample_tube_1.5ml, volume: 30 microliter.
# 12. Mixing sample_tube_1.5ml using gentle_pipetting method (10 repetitions).
# 13. Extracting from sample_tube_1.5ml using magnetic_bead_based method with KingFisher™ Duo Prime Purification System kit for DNA.
# 14. Eluting sample_tube_1.5ml with H2O (volume: 60 microliter).
# 15. Preparing PCR_master_mix (volume: 25 microliter) in PCR_mix_tube.
# 16. Adding DNA_template to PCR_mix_tube, volume: 2.5 microliter.
# 17. Aliquoting 25 microliter from PCR_mix_tube to PCR_plate (2 aliquots) of PCR_reaction_mix.
# 18. Running thermocycle on PCR_plate (volume: 25 microliter) - Data reference: D_nodosus_qPCR.
# 19. Running Sequence Detector analysis v2.3 for 7500 Real-Time PCR-System data (4 steps).
# ====================
# Converting the protocol to an executable JSON for the protocol generated given user query #3...
# Executing the JSON for the protocol generated given user query #3...
# Execution information:
# 1. Preparing 4x primer/probe stock (volume: 500:microliter) in primer_probe_stock.
# 2. Preparing 4x RT-PCR master mix (volume: 500:microliter) in rt_pcr_master_mix.
# 3. Transferring from primer_probe_stock to rt_pcr_master_mix, volume: 5:microliter.
# 4. Incubating container rt_pcr_master_mix for 2:minute at 55:celsius.
# 5. Incubating container rt_pcr_master_mix for 2:minute at 95:celsius.
# 6. Incubating container rt_pcr_master_mix for 30:minute at 60:celsius.
# 7. Incubating container rt_pcr_master_mix for 5:minute at 95:celsius.
# 8. Measuring fluorescence for rt_pcr_master_mix.
# 9. Preparing Q5 RT-PCR reaction mix (volume: 1500:microliter) in q5_rt_pcr_mix.
# 10. Running thermocycle on q5_rt_pcr_mix (volume: 10:microliter).
# 11. Manually adjust 5-8°C for container q5_rt_pcr_mix.
# 12. Preparing PCR reaction per well in pcr_plate.
# 13. Transferring from sample_rna to pcr_plate, volume: 4:microliter.
# 14. Incubating container pcr_plate for 2:minute at 55:celsius.
# 15. Incubating container pcr_plate for 2:minute at 95:celsius.
# ====================
# Converting the protocol to an executable JSON for the protocol generated given user query #4...
# Executing the JSON for the protocol generated given user query #4...
# Execution information:
# 1. Preparing 5'/3' primer working stock (volume: 20:microliter) at 500:nM each primer in primer_mix_tube.
# 2. Preparing PCR master mix (volume: 20:microliter) in pcr_master_mix_tube.
# 3. Transferring from pcr_master_mix_tube to pcr_tubes, volume: 20:milliliter.
# 4. Placing pipette tip with biomass at pcr_tube on ice.
# 5. Adding purified plasmid (0.5-1.0 ng/uL) to positive_control_tube, volume: 1:microliter.
# 6. Adding ddH2O to negative_control_tube, volume: 1:microliter.
# 7. Performing pipetting (volume: 10:microliter) from pcr_tubes to pcr_tubes.
# 8. Spinning container pcr_tubes for 30 second.
# 9. Running thermocycle on pcr_tubes (volume: 10:microliter).
# 10. Adding 6x DNA loading dye to pcr_tubes, volume: 4:microliter.
# 11. Spinning container pcr_tubes for 30 second.
# 12. Running gel electrophoresis and imaging for pcr_tubes (1.0% gel) with Ethidium Bromide stain.
# ====================
# Converting the protocol to an executable JSON for the protocol generated given user query #5...
# Executing the JSON for the protocol generated given user query #5...
# Execution information:
# 1. Preparing low-TE buffer with salmon sperm DNA (volume: 10 mL) in low_TE_buffer.
# 2. Preparing PhiX control dilution series in PhiX_calibrators_8strip.
# 3. Preparing 20x primers & probe mix in 20x_primers_probe_mix.
# 4. Preparing qPCR master mix in qPCR_master_mix.
# 5. Transferring from qPCR_master_mix to qPCR_plate, volume: 19 microliter.
# 6. Adding template (diluted library or calibrator) to qPCR_plate, volume: 1 microliter.
# 7. Running thermocycle on qPCR_plate (volume: 20 microliter).
# 8. Measuring Cq for qPCR_plate using qPCR instrument.
# 9. Run the following code snippet to perform calculation:
# ```python
#
# import csv
# import math
# import os
#
# # CONFIG: adjust these values as needed
# INPUT_CSV = "./output/qpcr_measurements.csv"            # input CSV produced by measure(...)
# OUTPUT_CSV = "./output/qpcr_measurements_with_conc.csv" # output CSV to write
# SLOPE = -3.32                             # standard curve slope (Cq vs log10(conc))
# INTERCEPT = 38.5                          # standard curve intercept
# LOG_BASE = 10                             # base of logarithm used in curve
# DEFAULT_DILUTION = 20.0                   # fallback dilution factor if missing in CSV
# PARAMETER_COLUMN = "parameter"
# VALUE_COLUMN = "measured_value"
# DILUTION_COLUMN = "dilution_factor"
# CQ_INDICATORS = ("cq", "ct")             # strings to detect Cq rows (case-insensitive)
#
# def _parse_num(s):
#     if s is None:
#         return None
#     s = str(s).strip()
#     if s == "":
#         return None
#     try:
#         return float(s)
#     except ValueError:
#         # extract numeric substring like "19.3 pM"
#         num = ''.join(ch for ch in s if (ch.isdigit() or ch in ".-eE"))
#         return float(num) if num else None
#
# # Read input CSV
# with open(INPUT_CSV, newline="", encoding="utf-8") as fh:
#     reader = csv.DictReader(fh)
#     rows = list(reader)
#     fieldnames = reader.fieldnames or []
#
# # Process rows: add two new columns
# for r in rows:
#     r["calculated_concentration"] = ""
#     r["corrected_concentration"] = ""
#     param = (r.get(PARAMETER_COLUMN) or "").lower()
#     if any(k in param for k in CQ_INDICATORS):
#         cq = _parse_num(r.get(VALUE_COLUMN))
#         if cq is None:
#             r["calculated_concentration"] = ""
#             r["corrected_concentration"] = ""
#         else:
#             if abs(SLOPE) < 1e-12:
#                 calc = float("nan")
#             else:
#                 exponent = (cq - INTERCEPT) / SLOPE
#                 try:
#                     calc = math.pow(LOG_BASE, exponent)
#                 except OverflowError:
#                     calc = float("inf")
#             # dilution
#             df = _parse_num(r.get(DILUTION_COLUMN))
#             if df is None:
#                 df = DEFAULT_DILUTION
#             corrected = calc * df if (calc is not None and not (isinstance(calc, float) and math.isnan(calc))) else ""
#             r["calculated_concentration"] = "" if calc in (None, "") else ("{:.6g}".format(calc) if isinstance(calc, (int, float)) else str(calc))
#             r["corrected_concentration"] = "" if corrected in (None, "") else ("{:.6g}".format(corrected) if isinstance(corrected, (int, float)) else str(corrected))
#
# # Write output CSV (preserve original fields, then append new ones)
# out_dir = os.path.dirname(OUTPUT_CSV) or "."
# os.makedirs(out_dir, exist_ok=True)
# extra_cols = ["calculated_concentration", "corrected_concentration"]
# out_fieldnames = list(fieldnames) + [c for c in extra_cols if c not in fieldnames]
#
# with open(OUTPUT_CSV, "w", newline="", encoding="utf-8") as fh:
#     writer = csv.DictWriter(fh, fieldnames=out_fieldnames)
#     writer.writeheader()
#     for r in rows:
#         writer.writerow({k: r.get(k, "") for k in out_fieldnames})
#
# print(f"Processed {len(rows)} rows. Output written to: {OUTPUT_CSV}")
#
# ```
# ====================
# Converting the protocol to an executable JSON for the protocol generated given user query #6...
# Executing the JSON for the protocol generated given user query #6...
# Execution information:
# 1. Preparing RT reaction mix (volume: 20:microliter) in RT_reaction_mix.
# 2. Aliquoting 20:microliter from RT_reaction_mix to reaction_plate.
# 3. Sealing container reaction_plate.
# 4. Centrifuging reaction_plate at 3000:rpm for 30 second for spin down contents and remove air bubbles.
# 5. Manually adjust ice for container reaction_plate.
# 6. Running thermocycle on reaction_plate (volume: 20:microliter).
# 7. Manually adjust 2-8 degC for short-term (<24 hours) for container reaction_plate.
# 8. Manually adjust -25 to -15 degC for long-term for container reaction_plate.
# 9. Preparing PCR reaction mix (volume: 20:microliter) in PCR_mix.
# 10. Inverting PCR_mix 5 times for mix.
# 11. Centrifuging PCR_mix at 3000:rpm for 30 second for spin down contents and eliminate air bubbles.
# 12. Transferring from PCR_mix to 384_well_reaction_plate, volume: 20:microliter.
# 13. Running thermocycle on 384_well_reaction_plate (volume: 20:microliter) - Data reference: qPCR_data.
# ====================
# Converting the protocol to an executable JSON for the protocol generated given user query #7...
# Executing the JSON for the protocol generated given user query #7...
# Execution information:
# 1. Preparing PCR reaction mix in PCR_tube.
# 2. Preparing DNA extraction solution in DNA_extraction_tube.
# 3. Incubating container thermocycler at thermocycler at 98 degC.
# 4. Adding tumor tissue to DNA_extraction_tube, weight: 20 µg.
# 5. Vortexing DNA_extraction_tube for 10 second.
# 6. Incubating container DNA_extraction_tube at heat_block for 6 minute at 65 degC.
# 7. Waiting for 3 minute.
# 8. Vortexing DNA_extraction_tube for 5 second.
# 9. Incubating container DNA_extraction_tube at heat_block for 2 minute at 98 degC.
# 10. Vortexing DNA_extraction_tube for 5 second.
# 11. Spinning container DNA_extraction_tube.
# 12. Incubating container DNA_extraction_tube at ice for 30 second.
# 13. Transferring from DNA_extraction_tube to PCR_tube, volume: 1 µL.
# 14. Placing PCR_tube at thermocycler.
# 15. Preparing ONT tagmentation mix in ONT_tagmentation_tube.
# 16. Preparing ONT sequencing buffer in sequencing_buffer_tube.
# 17. Preparing ONT flush buffer in flush_buffer_tube.
# 18. Mixing flush_buffer_tube using vortex method.
# 19. Spinning container flush_buffer_tube.
# 20. Filling flow_cell with mixed FB (Flush Buffer) (volume: 800 µL).
# 21. Incubating container flow_cell for 5 minute.
# 22. Performing sequencing on MinKNOW.
# 23. Running thermocycle on PCR_tube (volume: 10:microliter).
# 24. Incubating container PCR_tube at ice for 10 second.
# 25. Transferring from PCR_tube to ONT_tagmentation_tube, volume: 7.5 µL.
# 26. Tapping ONT_tagmentation_tube gentlely for mix.
# 27. Spinning container ONT_tagmentation_tube.
# 28. Placing ONT_tagmentation_tube at thermocycler.
# 29. Running thermocycle on ONT_tagmentation_tube (volume: 10:microliter).
# 30. Incubating container ONT_tagmentation_tube at ice for 10 second.
# 31. Adding ONT Rapid Adapter to ONT_tagmentation_tube, volume: 1 µL.
# 32. Tapping ONT_tagmentation_tube gentlely for mix.
# 33. Spinning container ONT_tagmentation_tube.
# 34. Incubating container ONT_tagmentation_tube for 5 minute.
# 35. Tapping ONT_tagmentation_tube gentlely for mix.
# 36. Spinning container ONT_tagmentation_tube.
# 37. Waiting for 4 minute.
# 38. Filling flow_cell with FB (Flush Buffer) (volume: 200 µL).
# ====================
# Converting the protocol to an executable JSON for the protocol generated given user query #8...
# Executing the JSON for the protocol generated given user query #8...
# Execution information:
# 1. Preparing Nuclease free water (volume: 4.35:microliter) in Nuclease_free_water.
# 2. Preparing RubV TAQMAN FWD 2015 (volume: 0.09:microliter) at 200:pmol/microliter in RubV_TAQMAN_FWD_2015.
# 3. Preparing RubV TAQMAN REV 2015 (volume: 0.09:microliter) at 200:pmol/microliter in RubV_TAQMAN_REV_2015.
# 4. Preparing RubV TAQMAN PRB 2015 (volume: 0.03:microliter) at 100:pmol/microliter in RubV_TAQMAN_PRB_2015.
# 5. Preparing 2X Reaction Mix (volume: 10:microliter) in 2X_Reaction_Mix.
# 6. Preparing SuperScript III/Platinum Taq Mix (volume: 0.4:microliter) in SuperScript_III_Platinum_Taq_Mix.
# 7. Preparing ROX Reference Dye (volume: 0.04:microliter) at 25:micromolar in ROX_Reference_Dye.
# 8. Transferring from Nuclease_free_water to Master_Mix, volume: 4.35:microliter.
# 9. Transferring from RubV_TAQMAN_FWD_2015 to Master_Mix, volume: 0.09:microliter.
# 10. Transferring from RubV_TAQMAN_REV_2015 to Master_Mix, volume: 0.09:microliter.
# 11. Transferring from RubV_TAQMAN_PRB_2015 to Master_Mix, volume: 0.03:microliter.
# 12. Transferring from 2X_Reaction_Mix to Master_Mix, volume: 10:microliter.
# 13. Transferring from SuperScript_III_Platinum_Taq_Mix to Master_Mix, volume: 0.4:microliter.
# 14. Transferring from ROX_Reference_Dye to Master_Mix, volume: 0.04:microliter.
# 15. Mixing Master_Mix using vortex method for 5:second.
# 16. Transferring from Master_Mix to Sample, volume: 15:microliter.
# 17. Running thermocycle on Sample (volume: 20:microliter).
# 18. Performing quality check on qPCR_result for analysis_criteria.
# ====================
# Converting the protocol to an executable JSON for the protocol generated given user query #9...
# Executing the JSON for the protocol generated given user query #9...
# Execution information:
# 1. Dissolving one colony in nuclease-free water in colony_tube (volume: 20:microliter).
# 2. Heating colony_tube to 80:celsius for 10:minute.
# 3. Adding Magnesium chloride (MgCl2) 25 mM to pcr_tube, volume: 4:microliter.
# 4. Adding 5X Colorless GoTaq Buffer to pcr_tube, volume: 5:microliter.
# 5. Adding PCR Nucleotide Mix 10 mM to pcr_tube, volume: 0.5:microliter.
# 6. Adding Forward primer 10 uM to pcr_tube, volume: 1:microliter.
# 7. Adding Reverse primer 10 uM to pcr_tube, volume: 1:microliter.
# 8. Adding GoTaq DNA polymerase (5u/uL) to pcr_tube, volume: 0.2:microliter.
# 9. Transferring from colony_tube to pcr_tube, volume: 10:microliter.
# 10. Adding Nuclease-free water to pcr_tube, volume: 3.3:microliter.
# 11. Mixing pcr_tube using gentle method.
# 12. Spinning container pcr_tube.
# 13. Running thermocycle on pcr_tube (volume: 10:microliter).
# 14. Incubating container pcr_tube at 4:celsius.
# ====================
# Converting the protocol to an executable JSON for the protocol generated given user query #10...
# Executing the JSON for the protocol generated given user query #10...
# Execution information:
# 1. Preparing lyophilised primers at 100 µM.
# 2. Preparing Pool 1 (100 µM) (volume: 490 µL) in Pool 1 (100 µM).
# 3. Preparing Pool 2 (100 µM) (volume: 490 µL) in Pool 2 (100 µM).
# 4. Preparing Pool LA1 (100 µM) in Pool LA1 (100 µM).
# 5. Diluting Pool 1 (100 µM) 10.0x with molecular grade water.
# 6. Diluting Pool 2 (100 µM) 10.0x with molecular grade water.
# 7. Diluting Pool LA1 (100 µM) 100.0x with molecular grade water.
# 8. Transferring from RT product to PCR tube, volume: 2.5 µL.
# 9. 2 validation errors for call[mix]
# target.Container
#   Input should be a valid dictionary or instance of Container [type=model_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.12/v/model_type
# target.str
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.12/v/string_type
# 10. Adding Q5 Hot Start High-Fidelity 2X Master Mix to PCR tube Pool 1, volume: 12.5 µL.
# 11. Adding Primer Pool 1 (10 µM) to PCR tube Pool 1, volume: 3.7 µL.
# 12. Adding Nuclease-free water to PCR tube Pool 1, volume: 6.3 µL.
# 13. Adding Q5 Hot Start High-Fidelity 2X Master Mix to PCR tube Pool 2, volume: 12.5 µL.
# 14. Adding Primer Pool 2 (10 µM) to PCR tube Pool 2, volume: 3.7 µL.
# 15. Adding Nuclease-free water to PCR tube Pool 2, volume: 6.3 µL.
# 16. Adding Q5 Hot Start High-Fidelity 2X Master Mix to PCR tube Pool LA1, volume: 12.5 µL.
# 17. Adding Primer Pool LA1 (1 µM) to PCR tube Pool LA1, volume: 3.7 µL.
# 18. Adding Nuclease-free water to PCR tube Pool LA1, volume: 6.3 µL.
# 19. Transferring from RT product to PCR tube Pool 1, volume: 2.5 µL.
# 20. Transferring from RT product to PCR tube Pool 2, volume: 2.5 µL.
# 21. Transferring from RT product to PCR tube Pool LA1, volume: 2.5 µL.
# 22. Spinning container PCR tube Pool 1.
# 23. Spinning container PCR tube Pool 2.
# 24. Spinning container PCR tube Pool LA1.
# 25. Running thermocycle on PCR tube Pool 1 (volume: 10:microliter).
# 26. Running thermocycle on PCR tube Pool 2 (volume: 10:microliter).
# 27. Running thermocycle on PCR tube Pool LA1 (volume: 10:microliter).
# 28. Transferring from PCR tube Pool 1 to Combined Pool 1+2.
# 29. Transferring from PCR tube Pool 2 to Combined Pool 1+2.
# 30. Adding SPRI beads to Combined Pool 1+2.
# 31. Incubating container Combined Pool 1+2 for 5 minute.
# 32. Pelletizing Combined Pool 1+2 using magnet method.
# 33. Discarding from Combined Pool 1+2.
# 34. Washing Combined Pool 1+2 with 80% ethanol using 200 µL, 2 repetitions.
# 35. Eluting Combined Pool 1+2 with elution buffer (volume: 30 µL).
# 36. Adding SPRI beads to PCR tube Pool LA1.
# 37. Incubating container PCR tube Pool LA1 for 5 minute.
# 38. Pelletizing PCR tube Pool LA1 using magnet method.
# 39. Discarding from PCR tube Pool LA1.
# 40. Washing PCR tube Pool LA1 with 80% ethanol using 200 µL, 2 repetitions.
# 41. Eluting PCR tube Pool LA1 with elution buffer (volume: 30 µL).
# 42. Measuring concentration for Combined Pool 1+2.
# 43. Measuring concentration for PCR tube Pool LA1.
# 44. Run the following code snippet to perform calculation:
# ```python
#
# import pandas as pd
# import numpy as np
#
# # 读取测量数据
# df_pool12 = pd.read_csv("measurements_pool12.csv")
# df_la1 = pd.read_csv("measurements_la1.csv")
#
# # 假设浓度数据在'concentration'列，单位为ng/µL
# # 这里需要根据实际CSV文件结构调整
# conc_pool12 = float(df_pool12.iloc[0]['concentration'])  # 假设第一行是浓度值
# conc_la1 = float(df_la1.iloc[0]['concentration'])
#
# # 计算所需体积
# volume_pool12 = 135 / conc_pool12  # 135 ng / 浓度 = 体积(µL)
# volume_la1 = 15.3 / conc_la1       # 15.3 ng / 浓度 = 体积(µL)
#
# # 计算需要添加的水体积
# total_volume = 30  # µL
# water_volume = total_volume - volume_pool12 - volume_la1
#
# print(f"Pool 1+2 concentration: {conc_pool12} ng/µL")
# print(f"Pool LA1 concentration: {conc_la1} ng/µL")
# print(f"Add {volume_pool12:.2f} µL of Pool 1+2")
# print(f"Add {volume_la1:.2f} µL of Pool LA1")
# print(f"Add {water_volume:.2f} µL nuclease-free water")
#
# # 保存计算结果
# with open("mixing_calculations.txt", "w") as f:
#     f.write(f"Pool 1+2 volume: {volume_pool12:.2f} µL\n")
#     f.write(f"Pool LA1 volume: {volume_la1:.2f} µL\n")
#     f.write(f"Nuclease-free water volume: {water_volume:.2f} µL\n")
#
# ```
# 45. Transferring from Combined Pool 1+2 to Final Amplicon Mix.
# 46. Transferring from PCR tube Pool LA1 to Final Amplicon Mix.
# 47. Adding Nuclease-free water to Final Amplicon Mix.
# 48. Mixing Final Amplicon Mix using pipetting method.
# ====================
#
# ✓ Disconnected
